# %% [markdown]
# # Midterm Demo Pipeline
#
# Use this notebook in Google Colab to produce report-ready ASR baseline results. Before running, upload this `tone_asr_starter` folder to Colab or mount Google Drive and `cd` into the project root.

# %% [markdown]
# ## 1. Check GPU

# %%
# !nvidia-smi || true
import torch
print('CUDA available:', torch.cuda.is_available())
print('Device:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')

# %% [markdown]
# ## 2. Go to Project Root
#
# If you uploaded the folder directly to Colab, adjust the path below. If using Drive, mount Drive first and set the correct path.

# %%
# Example paths. Keep the one that matches your Colab setup.
# from google.colab import drive
# drive.mount('/content/drive')

# %cd /content/tone_asr_starter
# !pwd
# !ls

# %% [markdown]
# ## 3. Install Dependencies

# %%
# !python -m pip install -q -r requirements.txt

# %% [markdown]
# ## 4. Run Fast Midterm Pipeline
#
# Default mode uses VIVOS plus a small controlled generated noise set. This is the fastest option for midterm evidence.

# %%
# !bash scripts/run_midterm_demo.sh

# %% [markdown]
# ## 5. View Result Tables

# %%
import pandas as pd

display(pd.read_csv('outputs/dataset_stats.csv'))
display(pd.read_csv('outputs/metrics_openai_whisper-base_clean.csv'))
display(pd.read_csv('outputs/metrics_openai_whisper-base_noisy_by_snr.csv'))

# %% [markdown]
# ## 6. Show Qualitative Examples

# %%
pred = pd.read_csv('outputs/openai_whisper-base_noisy.csv')
pred = pred[pred['text'].str.lower().str.strip() != pred['prediction'].str.lower().str.strip()]
display(pred[['snr', 'noise_type', 'text', 'prediction']].head(5))

# %% [markdown]
# ## 7. Open Ready-to-Copy Summary

# %%
from pathlib import Path
print(Path('outputs/midterm_summary.md').read_text(encoding='utf-8'))

# %% [markdown]
# ## Optional: Run PhoWhisper Baseline
#
# Run this only if the first pipeline completed and you still have GPU time.

# %%
# !MODEL=vinai/PhoWhisper-base bash scripts/run_midterm_demo.sh
